# %% [markdown]
# # Census Data

# %%
import pandas as pd

census = pd.read_csv("census_data.csv", header=1)

census_data = pd.DataFrame(census)
census_data = census_data[census_data.columns[range(67)]]

census_data
# Out:
#                   Geog  GeogKey  Total Population  \
# 0          Rogers Park        1             54991
# 1           West Ridge        2             71942
# 2               Uptown        3             56362
# 3       Lincoln Square        4             39493
# 4         North Center        5             31867
# ..                 ...      ...               ...
# 72  Washington Heights       73             26493
# 73     Mount Greenwood       74             19093
# 74         Morgan Park       75             22544
# 75              O'Hare       76             12756
# 76           Edgewater       77             56521
#
#     Not Hispanic or Latino, White alone  \
# 0                                 21618
# 1                                 30706
# 2                                 29098
# 3                                 24916
# 4                                 24634
# ..                                  ...
# 72                                  121
# ...
